# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

def covariance(df):
    return df['X'].cov(df['Y'])


def correlation(df):
    return df['X'].corr(df['Y'])

def plot(df):
    plt.scatter(df['X'], df['Y'], color='blue')
    plt.xlabel("X (Independent Variable)")
    plt.ylabel("Y (Dependent Variable)")
    plt.show()


x = np.linspace(-10, 10, 100)             # 100 points from -10 to 10
y = x**2 + np.random.normal(0, 10, 100)   # Quadratic relationship with noise

df = pd.DataFrame({'X': x, 'Y': y})

plot(df)

cov = covariance(df)
corr = correlation(df)

print("Covariance:", cov)
print("Pearson Correlation Coefficient:", corr)
# Out:
# Covariance: 2.369009966673994
# Pearson Correlation Coefficient: 0.012468415162746214
